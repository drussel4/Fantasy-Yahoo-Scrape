# %% [markdown]
# # <font color='teal'>Yahoo Fantasy Sports Roster Data Extraction</font>

# %%
# Import packages
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd
from datetime import datetime
import time

# %% [markdown]
# ## <font color='teal'>Must authenticate manually on phone before proceeding with scrape</font>

# %%
# League base url and team count
league_url = 'https://football.fantasysports.yahoo.com/f1/659111/'
teams = 12
login_email = 'trojanh8er143@yahoo.com'
latest_week = 16
week_tails_range = (1, latest_week)

# %%
# Dict containing team names to associate to trailing url int
team_ints_to_names = {
    1:'Child Butt Doctor',
    2:'CreamTeam Curdlers',
    3:'First Round Exit',
    4:'CeeDeeZ Rugged Nuts', # OOO Till Playoffs
    5:'JohnDavidBootyShorts',
    6:'Bidet to You Sir',
    7:'Doctor Steal Yo Girl',
    8:'Betty Boop Would',
    9:'OnlyFans Cam Girl',
    10:'My Dick Sucks',
    11:'Florida Man',
    12:'North Source Boys', # 'axel\'s Notable Team',
}

# %%
position_players_count_dict = {
    'QB':1,
    'RB':2,
    'WR':2,
    'TE':1,
    'W/R/T':2,
    'DEF':1
}

# %%
position_abbrevs_list = ['QB', 'RB', 'WR', 'TE', 'DEF', 'K',
                         'WR,RB', 'RB,WR', 'QB,WR', 'QB,RB',
                         'QB,TE', 'WR,TE', 'TE,WR', 'TE,RB']

# %%
# Align driver
DRIVER_PATH = '\\Users\\David\\Desktop\\Python\\chromedriver\\chromedriver.exe'
driver = webdriver.Chrome(executable_path=DRIVER_PATH)
driver.get(league_url)

# %%
# Login steps xpaths
username_xpath = '//*[@id="login-username"]'
next_button_xpath = '//*[@id="login-signin"]'

# Send email login
driver.find_element_by_xpath(username_xpath).send_keys(login_email)

# Click next, then authenticate on phone
driver.find_element_by_xpath(next_button_xpath).click()

# %% [markdown]
# ## <font color='teal'>Must authenticate manually on phone before proceeding with scrape</font>

# %%
# Build urls to visit
urls_list = []
for team in range(1, teams+1):
    for week in range (1, latest_week+1):
        page_nav = league_url + str(team) + '/team?&week=' + str(week)
        urls_list.append(page_nav)

# %%
# Function to retrieve roster data
def rosterExtract(url, team_ints_to_names):
    
    try:

        checkpoint = 0

        team_name = team_ints_to_names[int(
            url.split('659111/', 1)[1].split('/', 1)[0])] # retrieve team
        week_num = int(url.split('team?&week=', 1)[1]) # retrieve week
        print('Beginning', team_name, 'week', week_num)
        driver.get(url) # navigate to each team's roster per week
        time.sleep(1) # force wait for loading
        
        checkpoint = 1

        # Loop to retrieve players by href
        players_list = []
        elements = driver.find_elements_by_xpath('//a[contains(@href, "https://sports.yahoo.com/nfl/")]')
        for element in elements:
            if element.text != '' and\
            '@' not in element.text and\
            'StatTracker' not in element.text and\
            'vs' not in element.text:
                players_list.append(element.text)

        checkpoint = 2
        
        # Loop to retrieve game statuses by class
        game_status_list = []
        win_loss_list = []
        elements = driver.find_elements_by_class_name('ysf-game-status')
        for element in elements:
            if 'Bye' in element.text:
                game_status_list.append('Bye')
            elif 'vs' in element.text:
                game_status_list.append('Home')
            elif '@' in element.text:
                game_status_list.append('Away')
            else:
                game_status_list.append('N/A')
        for element in elements:
            if 'Bye' in element.text:
                win_loss_list.append('Bye')
            elif 'Final W' in element.text:
                win_loss_list.append('W')
            elif 'Final L' in element.text:
                win_loss_list.append('L')
            elif 'Final T' in element.text:
                win_loss_list.append('T')
            else:
                win_loss_list.append('N/A')
        
        checkpoint = 3

        # Loop to retrieve positions by class
        positions_list = []
        elements = driver.find_elements_by_class_name('pos-label')
        for element in elements:
            positions_list.append(element.text)

        checkpoint = 4

        # Loop to retrieve player teams and positions by class
        player_team_list = []
        player_pos_list = []
        elements = driver.find_elements_by_class_name('Fz-xxs')
        for element in elements:
            if ' - ' in element.text:
                element_tuple = element.text.split(' - ', 1)
                team = element_tuple[0]
                pos = element_tuple[1]
                if pos in position_abbrevs_list:
                    player_team_list.append(team)
                    player_pos_list.append(pos)

        checkpoint = 5

        # Loop to retrieve points by href
        points_as_strings = []
        counter = 0
        elements = driver.find_elements_by_xpath('//a[contains(@href, "#pps-")]')
        for element in elements:
            if element.text != '':
                points_as_strings.append(element.text)
        points_as_floats = [float(pt) for pt in points_as_strings] # Convert strings to floats
        
        checkpoint = 6
        
        # Insert zero floats where player on bye
        game_status_indexes = []
        counter = 0
        for status in game_status_list:
            counter += 1
            if status == 'Bye':
                game_status_indexes.append(counter-1)
        for i in game_status_indexes:
            points_as_floats.insert(i, 0.00)

        checkpoint = 7
                
        # Insert "Empty" or zero float to lists where Bye week is Null
        empty_spot_indexes = []
        counter = 0
        for status in game_status_list:
            counter += 1
            if status == 'N/A':
                empty_spot_indexes.append(counter-1)
        for i in empty_spot_indexes:
            players_list.insert(i, 'Empty')
            player_team_list.insert(i, 'Empty')
            player_pos_list.insert(i, 'Empty')
            points_as_floats.insert(i, 0.0)
        
        checkpoint = 8

        # Build table from lists, write to DataFrame
        roster_df = pd.DataFrame(
            columns=['Fantasy Team', 'Week', 'Player', 'Roster Status', 'Game Status',
                     'Win-Loss Status', 'Player Team', 'Position', 'Points'])
        roster_df['Player'] = players_list
        roster_df['Roster Status'] = positions_list
        roster_df['Game Status'] = game_status_list
        roster_df['Win-Loss Status'] = win_loss_list
        roster_df['Player Team'] = player_team_list
        roster_df['Position'] = player_pos_list
        roster_df['Points'] = points_as_floats
        roster_df['Fantasy Team'] = team_name
        roster_df['Week'] = week_num

        print('Completed', team_name, 'week', week_num)
        print('')
        print('---')
        print('')

        return roster_df
    
    except Exception as e:
        print('Failed at checkpoint', str(checkpoint))
        print(e)
        
        return (players_list, positions_list, player_team_list,
                player_pos_list, points_as_floats);

# %%
# %%time

# Run function, append to master DataFrame
master_rosters_df = pd.DataFrame(
    columns=['Fantasy Team', 'Week', 'Player', 'Roster Status', 'Game Status',
             'Win-Loss Status', 'Player Team', 'Position', 'Points'])

for url in urls_list:
    temp_df = rosterExtract(url, team_ints_to_names)
    master_rosters_df = pd.concat([master_rosters_df, temp_df], axis=0)
# Out:
# Beginning Child Butt Doctor week 1
# Completed Child Butt Doctor week 1
#
# ---
#
# Beginning Child Butt Doctor week 2
# Completed Child Butt Doctor week 2
#
# ---
#
# Beginning Child Butt Doctor week 3
# Completed Child Butt Doctor week 3
#
# ---
#
# Beginning Child Butt Doctor week 4
# Completed Child Butt Doctor week 4
#
# ---
#
# Beginning Child Butt Doctor week 5
# Completed Child Butt Doctor week 5
#
# ---
#
# Beginning Child Butt Doctor week 6
# Completed Child Butt Doctor week 6
#
# ---
#
# Beginning Child Butt Doctor week 7
# Completed Child Butt Doctor week 7
#
# ---
#
# Beginning Child Butt Doctor week 8
# Completed Child Butt Doctor week 8
#
# ---
#
# Beginning Child Butt Doctor week 9
# Completed Child Butt Doctor week 9
#
# ---
#
# Beginning Child Butt Doctor week 10
# Completed Child Butt Doctor week 10
#
# ---
#
# Beginning Child Butt Doctor week 11
# Completed Child Butt Doctor week 11
#
# ---
#
# Beginning Child Butt Doctor week 12
# Completed Child Butt Doctor week 12
#
# ---
#
# Beginning Child Butt Doctor week 13
# Completed Child Butt Doctor week 13
#
# ---
#
# Beginning Child Butt Doctor week 14
# Completed Child Butt Doctor week 14
#
# ---
#
# Beginning Child Butt Doctor week 15
# Completed Child Butt Doctor week 15
#
# ---
#
# Beginning Child Butt Doctor week 16
# Completed Child Butt Doctor week 16
#
# ---
#
# Beginning CreamTeam Curdlers week 1
# Completed CreamTeam Curdlers week 1
#
# ---
#
# Beginning CreamTeam Curdlers week 2
# Completed CreamTeam Curdlers week 2
#
# ---
#
# Beginning CreamTeam Curdlers week 3
# Completed CreamTeam Curdlers week 3
#
# ---
#
# Beginning CreamTeam Curdlers week 4
# Completed CreamTeam Curdlers week 4
#
# ---
#
# Beginning CreamTeam Curdlers week 5
# Completed CreamTeam Curdlers week 5
#
# ---
#
# Beginning CreamTeam Curdlers week 6
# Completed CreamTeam Curdlers week 6
#
# ---
#
# Beginning CreamTeam Curdlers week 7
# Completed CreamTeam Curdlers week 7
#
# ---
#
# Beginning CreamTeam Curdlers week 8
# Completed CreamTeam Curdlers week 8
#
# ---
#
# Beginning CreamTeam Curdlers week 9
# Completed CreamTeam Curdlers week 9
#
# ---
#
# Beginning CreamTeam Curdlers week 10
# Completed CreamTeam Curdlers week 10
#
# ---
#
# Beginning CreamTeam Curdlers week 11
# Completed CreamTeam Curdlers week 11
#
# ---
#
# Beginning CreamTeam Curdlers week 12
# Completed CreamTeam Curdlers week 12
#
# ---
#
# Beginning CreamTeam Curdlers week 13
# Completed CreamTeam Curdlers week 13
#
# ---
#
# Beginning CreamTeam Curdlers week 14
# Completed CreamTeam Curdlers week 14
#
# ---
#
# Beginning CreamTeam Curdlers week 15
# Completed CreamTeam Curdlers week 15
#
# ---
#
# Beginning CreamTeam Curdlers week 16
# Completed CreamTeam Curdlers week 16
#
# ---
#
# Beginning First Round Exit week 1
# Completed First Round Exit week 1
#
# ---
#
# Beginning First Round Exit week 2
# Completed First Round Exit week 2
#
# ---
#
# Beginning First Round Exit week 3
# Completed First Round Exit week 3
#
# ---
#
# Beginning First Round Exit week 4
# Completed First Round Exit week 4
#
# ---
#
# Beginning First Round Exit week 5
# Completed First Round Exit week 5
#
# ---
#
# Beginning First Round Exit week 6
# Completed First Round Exit week 6
#
# ---
#
# Beginning First Round Exit week 7
# Completed First Round Exit week 7
#
# ---
#
# Beginning First Round Exit week 8
# Completed First Round Exit week 8
#
# ---
#
# Beginning First Round Exit week 9
# Completed First Round Exit week 9
#
# ---
#
# Beginning First Round Exit week 10
# Completed First Round Exit week 10
#
# ---
#
# Beginning First Round Exit week 11
# Completed First Round Exit week 11
#
# ---
#
# Beginning First Round Exit week 12
# Completed First Round Exit week 12
#
# ---
#
# Beginning First Round Exit week 13
# Completed First Round Exit week 13
#
# ---
#
# Beginning First Round Exit week 14
# Completed First Round Exit week 14
#
# ---
#
# Beginning First Round Exit week 15
# Completed First Round Exit week 15
#
# ---
#
# Beginning First Round Exit week 16
# Completed First Round Exit week 16
#
# ---
#
# Beginning OOO Till Playoffs week 1
# Completed OOO Till Playoffs week 1
#
# ---
#
# Beginning OOO Till Playoffs week 2
# Completed OOO Till Playoffs week 2
#
# ---
#
# Beginning OOO Till Playoffs week 3
# Completed OOO Till Playoffs week 3
#
# ---
#
# Beginning OOO Till Playoffs week 4
# Completed OOO Till Playoffs week 4
#
# ---
#
# Beginning OOO Till Playoffs week 5
# Completed OOO Till Playoffs week 5
#
# ---
#
# Beginning OOO Till Playoffs week 6
# Completed OOO Till Playoffs week 6
#
# ---
#
# Beginning OOO Till Playoffs week 7
# Completed OOO Till Playoffs week 7
#
# ---
#
# Beginning OOO Till Playoffs week 8
# Completed OOO Till Playoffs week 8
#
# ---
#
# Beginning OOO Till Playoffs week 9
# Completed OOO Till Playoffs week 9
#
# ---
#
# Beginning OOO Till Playoffs week 10
# Completed OOO Till Playoffs week 10
#
# ---
#
# Beginning OOO Till Playoffs week 11
# Completed OOO Till Playoffs week 11
#
# ---
#
# Beginning OOO Till Playoffs week 12
# Completed OOO Till Playoffs week 12
#
# ---
#
# Beginning OOO Till Playoffs week 13
# Completed OOO Till Playoffs week 13
#
# ---
#
# Beginning OOO Till Playoffs week 14
# Completed OOO Till Playoffs week 14
#
# ---
#
# Beginning OOO Till Playoffs week 15
# Completed OOO Till Playoffs week 15
#
# ---
#
# Beginning OOO Till Playoffs week 16
# Completed OOO Till Playoffs week 16
#
# ---
#
# Beginning JohnDavidBootyShorts week 1
# Completed JohnDavidBootyShorts week 1
#
# ---
#
# Beginning JohnDavidBootyShorts week 2
# Completed JohnDavidBootyShorts week 2
#
# ---
#
# Beginning JohnDavidBootyShorts week 3
# Completed JohnDavidBootyShorts week 3
#
# ---
#
# Beginning JohnDavidBootyShorts week 4
# Completed JohnDavidBootyShorts week 4
#
# ---
#
# Beginning JohnDavidBootyShorts week 5
# Completed JohnDavidBootyShorts week 5
#
# ---
#
# Beginning JohnDavidBootyShorts week 6
# Completed JohnDavidBootyShorts week 6
#
# ---
#
# Beginning JohnDavidBootyShorts week 7
# Completed JohnDavidBootyShorts week 7
#
# ---
#
# Beginning JohnDavidBootyShorts week 8
# Completed JohnDavidBootyShorts week 8
#
# ---
#
# Beginning JohnDavidBootyShorts week 9
# Completed JohnDavidBootyShorts week 9
#
# ---
#
# Beginning JohnDavidBootyShorts week 10
# Completed JohnDavidBootyShorts week 10
#
# ---
#
# Beginning JohnDavidBootyShorts week 11
# Completed JohnDavidBootyShorts week 11
#
# ---
#
# Beginning JohnDavidBootyShorts week 12
# Completed JohnDavidBootyShorts week 12
#
# ---
#
# Beginning JohnDavidBootyShorts week 13
# Completed JohnDavidBootyShorts week 13
#
# ---
#
# Beginning JohnDavidBootyShorts week 14
# Completed JohnDavidBootyShorts week 14
#
# ---
#
# Beginning JohnDavidBootyShorts week 15
# Completed JohnDavidBootyShorts week 15
#
# ---
#
# Beginning JohnDavidBootyShorts week 16
# Completed JohnDavidBootyShorts week 16
#
# ---
#
# Beginning Bidet to You Sir week 1
# Completed Bidet to You Sir week 1
#
# ---
#
# Beginning Bidet to You Sir week 2
# Completed Bidet to You Sir week 2
#
# ---
#
# Beginning Bidet to You Sir week 3
# Completed Bidet to You Sir week 3
#
# ---
#
# Beginning Bidet to You Sir week 4
# Completed Bidet to You Sir week 4
#
# ---
#
# Beginning Bidet to You Sir week 5
# Completed Bidet to You Sir week 5
#
# ---
#
# Beginning Bidet to You Sir week 6
# Completed Bidet to You Sir week 6
#
# ---
#
# Beginning Bidet to You Sir week 7
# Completed Bidet to You Sir week 7
#
# ---
#
# Beginning Bidet to You Sir week 8
# Completed Bidet to You Sir week 8
#
# ---
#
# Beginning Bidet to You Sir week 9
# Completed Bidet to You Sir week 9
#
# ---
#
# Beginning Bidet to You Sir week 10
# Completed Bidet to You Sir week 10
#
# ---
#
# Beginning Bidet to You Sir week 11
# Completed Bidet to You Sir week 11
#
# ---
#
# Beginning Bidet to You Sir week 12
# Completed Bidet to You Sir week 12
#
# ---
#
# Beginning Bidet to You Sir week 13
# Completed Bidet to You Sir week 13
#
# ---
#
# Beginning Bidet to You Sir week 14
# Completed Bidet to You Sir week 14
#
# ---
#
# Beginning Bidet to You Sir week 15
# Completed Bidet to You Sir week 15
#
# ---
#
# Beginning Bidet to You Sir week 16
# Completed Bidet to You Sir week 16
#
# ---
#
# Beginning Doctor Steal Yo Girl week 1
# Completed Doctor Steal Yo Girl week 1
#
# ---
#
# Beginning Doctor Steal Yo Girl week 2
# Completed Doctor Steal Yo Girl week 2
#
# ---
#
# Beginning Doctor Steal Yo Girl week 3
# Completed Doctor Steal Yo Girl week 3
#
# ---
#
# Beginning Doctor Steal Yo Girl week 4
# Completed Doctor Steal Yo Girl week 4
#
# ---
#
# Beginning Doctor Steal Yo Girl week 5
# Completed Doctor Steal Yo Girl week 5
#
# ---
#
# Beginning Doctor Steal Yo Girl week 6
# Completed Doctor Steal Yo Girl week 6
#
# ---
#
# Beginning Doctor Steal Yo Girl week 7
# Completed Doctor Steal Yo Girl week 7
#
# ---
#
# Beginning Doctor Steal Yo Girl week 8
# Completed Doctor Steal Yo Girl week 8
#
# ---
#
# Beginning Doctor Steal Yo Girl week 9
# Completed Doctor Steal Yo Girl week 9
#
# ---
#
# Beginning Doctor Steal Yo Girl week 10
# Completed Doctor Steal Yo Girl week 10
#
# ---
#
# Beginning Doctor Steal Yo Girl week 11
# Completed Doctor Steal Yo Girl week 11
#
# ---
#
# Beginning Doctor Steal Yo Girl week 12
# Completed Doctor Steal Yo Girl week 12
#
# ---
#
# Beginning Doctor Steal Yo Girl week 13
# Completed Doctor Steal Yo Girl week 13
#
# ---
#
# Beginning Doctor Steal Yo Girl week 14
# Completed Doctor Steal Yo Girl week 14
#
# ---
#
# Beginning Doctor Steal Yo Girl week 15
# Completed Doctor Steal Yo Girl week 15
#
# ---
#
# Beginning Doctor Steal Yo Girl week 16
# Completed Doctor Steal Yo Girl week 16
#
# ---
#
# Beginning Betty Boop Would week 1
# Completed Betty Boop Would week 1
#
# ---
#
# Beginning Betty Boop Would week 2
# Completed Betty Boop Would week 2
#
# ---
#
# Beginning Betty Boop Would week 3
# Completed Betty Boop Would week 3
#
# ---
#
# Beginning Betty Boop Would week 4
# Completed Betty Boop Would week 4
#
# ---
#
# Beginning Betty Boop Would week 5
# Completed Betty Boop Would week 5
#
# ---
#
# Beginning Betty Boop Would week 6
# Completed Betty Boop Would week 6
#
# ---
#
# Beginning Betty Boop Would week 7
# Completed Betty Boop Would week 7
#
# ---
#
# Beginning Betty Boop Would week 8
# Completed Betty Boop Would week 8
#
# ---
#
# Beginning Betty Boop Would week 9
# Completed Betty Boop Would week 9
#
# ---
#
# Beginning Betty Boop Would week 10
# Completed Betty Boop Would week 10
#
# ---
#
# Beginning Betty Boop Would week 11
# Completed Betty Boop Would week 11
#
# ---
#
# Beginning Betty Boop Would week 12
# Completed Betty Boop Would week 12
#
# ---
#
# Beginning Betty Boop Would week 13
# Completed Betty Boop Would week 13
#
# ---
#
# Beginning Betty Boop Would week 14
# Completed Betty Boop Would week 14
#
# ---
#
# Beginning Betty Boop Would week 15
# Completed Betty Boop Would week 15
#
# ---
#
# Beginning Betty Boop Would week 16
# Completed Betty Boop Would week 16
#
# ---
#
# Beginning OnlyFans Cam Girl week 1
# Completed OnlyFans Cam Girl week 1
#
# ---
#
# Beginning OnlyFans Cam Girl week 2
# Completed OnlyFans Cam Girl week 2
#
# ---
#
# Beginning OnlyFans Cam Girl week 3
# Completed OnlyFans Cam Girl week 3
#
# ---
#
# Beginning OnlyFans Cam Girl week 4
# Completed OnlyFans Cam Girl week 4
#
# ---
#
# Beginning OnlyFans Cam Girl week 5
# Completed OnlyFans Cam Girl week 5
#
# ---
#
# Beginning OnlyFans Cam Girl week 6
# Completed OnlyFans Cam Girl week 6
#
# ---
#
# Beginning OnlyFans Cam Girl week 7
# Completed OnlyFans Cam Girl week 7
#
# ---
#
# Beginning OnlyFans Cam Girl week 8
# Completed OnlyFans Cam Girl week 8
#
# ---
#
# Beginning OnlyFans Cam Girl week 9
# Completed OnlyFans Cam Girl week 9
#
# ---
#
# Beginning OnlyFans Cam Girl week 10
# Completed OnlyFans Cam Girl week 10
#
# ---
#
# Beginning OnlyFans Cam Girl week 11
# Completed OnlyFans Cam Girl week 11
#
# ---
#
# Beginning OnlyFans Cam Girl week 12
# Completed OnlyFans Cam Girl week 12
#
# ---
#
# Beginning OnlyFans Cam Girl week 13
# Completed OnlyFans Cam Girl week 13
#
# ---
#
# Beginning OnlyFans Cam Girl week 14
# Completed OnlyFans Cam Girl week 14
#
# ---
#
# Beginning OnlyFans Cam Girl week 15
# Completed OnlyFans Cam Girl week 15
#
# ---
#
# Beginning OnlyFans Cam Girl week 16
# Completed OnlyFans Cam Girl week 16
#
# ---
#
# Beginning My Dick Sucks week 1
# Completed My Dick Sucks week 1
#
# ---
#
# Beginning My Dick Sucks week 2
# Completed My Dick Sucks week 2
#
# ---
#
# Beginning My Dick Sucks week 3
# Completed My Dick Sucks week 3
#
# ---
#
# Beginning My Dick Sucks week 4
# Completed My Dick Sucks week 4
#
# ---
#
# Beginning My Dick Sucks week 5
# Completed My Dick Sucks week 5
#
# ---
#
# Beginning My Dick Sucks week 6
# Completed My Dick Sucks week 6
#
# ---
#
# Beginning My Dick Sucks week 7
# Completed My Dick Sucks week 7
#
# ---
#
# Beginning My Dick Sucks week 8
# Completed My Dick Sucks week 8
#
# ---
#
# Beginning My Dick Sucks week 9
# Completed My Dick Sucks week 9
#
# ---
#
# Beginning My Dick Sucks week 10
# Completed My Dick Sucks week 10
#
# ---
#
# Beginning My Dick Sucks week 11
# Completed My Dick Sucks week 11
#
# ---
#
# Beginning My Dick Sucks week 12
# Completed My Dick Sucks week 12
#
# ---
#
# Beginning My Dick Sucks week 13
# Completed My Dick Sucks week 13
#
# ---
#
# Beginning My Dick Sucks week 14
# Completed My Dick Sucks week 14
#
# ---
#
# Beginning My Dick Sucks week 15
# Completed My Dick Sucks week 15
#
# ---
#
# Beginning My Dick Sucks week 16
# Completed My Dick Sucks week 16
#
# ---
#
# Beginning Florida Man week 1
# Completed Florida Man week 1
#
# ---
#
# Beginning Florida Man week 2
# Completed Florida Man week 2
#
# ---
#
# Beginning Florida Man week 3
# Completed Florida Man week 3
#
# ---
#
# Beginning Florida Man week 4
# Completed Florida Man week 4
#
# ---
#
# Beginning Florida Man week 5
# Completed Florida Man week 5
#
# ---
#
# Beginning Florida Man week 6
# Completed Florida Man week 6
#
# ---
#
# Beginning Florida Man week 7
# Completed Florida Man week 7
#
# ---
#
# Beginning Florida Man week 8
# Completed Florida Man week 8
#
# ---
#
# Beginning Florida Man week 9
# Completed Florida Man week 9
#
# ---
#
# Beginning Florida Man week 10
# Completed Florida Man week 10
#
# ---
#
# Beginning Florida Man week 11
# Completed Florida Man week 11
#
# ---
#
# Beginning Florida Man week 12
# Completed Florida Man week 12
#
# ---
#
# Beginning Florida Man week 13
# Completed Florida Man week 13
#
# ---
#
# Beginning Florida Man week 14
# Completed Florida Man week 14
#
# ---
#
# Beginning Florida Man week 15
# Completed Florida Man week 15
#
# ---
#
# Beginning Florida Man week 16
# Completed Florida Man week 16
#
# ---
#
# Beginning North Source Boys week 1
# Completed North Source Boys week 1
#
# ---
#
# Beginning North Source Boys week 2
# Completed North Source Boys week 2
#
# ---
#
# Beginning North Source Boys week 3
# Completed North Source Boys week 3
#
# ---
#
# Beginning North Source Boys week 4
# Completed North Source Boys week 4
#
# ---
#
# Beginning North Source Boys week 5
# Completed North Source Boys week 5
#
# ---
#
# Beginning North Source Boys week 6
# Completed North Source Boys week 6
#
# ---
#
# Beginning North Source Boys week 7
# Completed North Source Boys week 7
#
# ---
#
# Beginning North Source Boys week 8
# Completed North Source Boys week 8
#
# ---
#
# Beginning North Source Boys week 9
# Completed North Source Boys week 9
#
# ---
#
# Beginning North Source Boys week 10
# Completed North Source Boys week 10
#
# ---
#
# Beginning North Source Boys week 11
# Completed North Source Boys week 11
#
# ---
#
# Beginning North Source Boys week 12
# Completed North Source Boys week 12
#
# ---
#
# Beginning North Source Boys week 13
# Completed North Source Boys week 13
#
# ---
#
# Beginning North Source Boys week 14
# Completed North Source Boys week 14
#
# ---
#
# Beginning North Source Boys week 15
# Completed North Source Boys week 15
#
# ---
#
# Beginning North Source Boys week 16
# Completed North Source Boys week 16
#
# ---
#
# Wall time: 30min 10s

# %%
# master_rosters_df.head()

# %%
# Write DataFrame to csv in project directory
dt_string = datetime.now().strftime('%Y%m%d_%H%M%S')
master_rosters_df.to_csv(
    'C:\\Users\\David\\Desktop\\Fantasy Football\\Blastoff Boys Rosters\\Actual Rosters\\blastoff_boys_roster_scrape_{}.csv'.format(dt_string))

# %% [markdown]
# ## <font color='orange'>Calculate Optimal Lineup</font>

# %%
# Loop through teams and weeks, constructing optimal lineups
team_holding_df = pd.DataFrame(columns=master_rosters_df.columns)
for team in list(team_ints_to_names.values()):
    weekly_holding_df = pd.DataFrame(columns=master_rosters_df.columns)
    for week in range (1, latest_week+1):

        # Create that week's df
        condensed_df = master_rosters_df[(
            master_rosters_df['Fantasy Team']==team) & (master_rosters_df['Week']==week)]

        # Retrieve optimal scorers for singular positions (excluding flex)
        holding_df = pd.DataFrame(columns=master_rosters_df.columns)
        for pos in ['QB', 'RB', 'WR', 'TE', 'DEF']: # 'W/R/T'
            position_df = condensed_df[(condensed_df['Position'] == pos)]
            pos_count = position_players_count_dict[pos]
            opt_pos_df = position_df.sort_values('Points', ascending=False).iloc[0:pos_count]
            holding_df = pd.concat([holding_df, opt_pos_df], axis=0)

        # Remove chosen players from orig df by index, filter to W/R/T, calc optimal flexes
        flex_only_df = condensed_df.copy()
        flex_only_df.drop(holding_df.index, inplace=True)
        flex_only_df = flex_only_df[(
            flex_only_df['Position'].isin(['RB', 'WR', 'TE', 'WR,RB', 'RB,WR', 'QB,WR',
                                           'QB,RB', 'QB,TE', 'WR,TE', 'TE,WR', 'TE,RB']))]
        flex_count = position_players_count_dict['W/R/T']
        opt_flex_df = flex_only_df.sort_values('Points', ascending=False).iloc[0:flex_count]
        holding_df = pd.concat([holding_df, opt_flex_df], axis=0)
        holding_df.sort_index(ascending=True, inplace=True)

        # Concat week's optimal roster to holding
        weekly_holding_df = pd.concat([weekly_holding_df, holding_df], axis=0)
    
    # Concat team's seasonal optimals to holding
    team_holding_df = pd.concat([team_holding_df, weekly_holding_df], axis=0)

# %%
# team_holding_df.head()

# %%
# Write DataFrame to csv in project directory
dt_string = datetime.now().strftime('%Y%m%d_%H%M%S')
team_holding_df.to_csv(
    'C:\\Users\\David\\Desktop\\Fantasy Football\\Blastoff Boys Rosters\\Optimal Rosters\\blastoff_boys_optimal_rosters_{}.csv'.format(dt_string))

# %% [markdown]
# ## <font color='teal'>Transactions Data</font>

# %%
# Navigate to transactions page
transactions_url = league_url + 'transactions'
driver.get(transactions_url) # navigate to each team's roster per week

# Navigate to faab bids history
driver.find_element_by_partial_link_text('FAB Offers').click()
time.sleep(1) # force wait for loading

# %%
# In order to parse other bids section, need to remove apostraphes, then write back for lookup
non_apostraphe_team_names = []
for team in list(team_ints_to_names.values()):
    non_apostraphe_team_names.append(team.replace("'",''))
apostraphe_lookup_dict = dict(zip(non_apostraphe_team_names, list(team_ints_to_names.values())))

# %%
# Establish df to append to
master_faab_df = pd.DataFrame(
    columns=['Player Name', 'Player Team', 'Player Position', 'Bid Date', 'Winning Team', 'Winning Bid',
             'Second Bid', 'Second Bid Team', 'Last Bid', 'Last Bid Team', 'Other Bids'])

while True:
    
    # Loop to retrieve transactions
    bid_player_names_list = []
    bid_player_teams_list = []
    bid_player_pos_list = []
    winning_offers_list = []
    second_offers_list = []
    second_team_list = []
    last_offers_list = []
    last_team_list = []
    other_bids_list = []
    elements = driver.find_elements_by_class_name('No-pstart')
    for element in elements:
        player_name_team = element.text.split('\n')[0].split(' - ')[0]
        last_space_in_player_name = max(
            list([pos for pos, char in enumerate(player_name_team) if char == ' ']))
        player_name = player_name_team[0:last_space_in_player_name]
        player_team = player_name_team[last_space_in_player_name + 1:]
        player_pos = element.text.split('\n')[0].split(' - ')[1].split(' ')[0]
        bid_player_pos_list.append(player_pos)
        # On 12.29.2020 found the below loop double appends flex players (e.g.,
        # having WR,RB appends both WR and RB rather than one element: WR,RB
#         for pos in position_abbrevs_list:
#             if pos in player_pos:
#                 bid_player_pos_list.append(pos)
        winning_offer = int(element.text.split('\n')[1].replace(' Winning Offer', '').replace('$',''))
        
        # Retrieve info about other bids for this player
        other_bids = str(element.text.split('\n')[2:]).replace(' (Lower Offer)', '').replace(
            ' (Lower waiver priority)', '').replace(' (Invalid claim due to previous transaction)', '').replace(
            '[', '').replace(']', '').replace("'", "").replace('"', '')
        bids_split = other_bids.split(',')
        bids_split_cleaned = []
        teams_making_bids = []
        for bid in bids_split:
            bid = bid.replace('$', '')
            for team in non_apostraphe_team_names:
                if team in bid:
                    teams_making_bids.append(apostraphe_lookup_dict[team])
                    bid = bid.replace(team, '')
            bid = bid.replace(' ', '')
            bids_split_cleaned.append(int(bid))
        max_bid = max(bids_split_cleaned) # Find max bid and associated team
        index_max_bid = bids_split_cleaned.index(max_bid)
        team_max_bid = teams_making_bids[index_max_bid]
        second_offers_list.append(max_bid)
        second_team_list.append(team_max_bid)
        min_bid = min(bids_split_cleaned) # Find min bid and associated team
        index_min_bid = bids_split_cleaned.index(min_bid)
        team_min_bid = teams_making_bids[index_min_bid]
        last_offers_list.append(min_bid)
        last_team_list.append(team_min_bid)
        
        # Append other elements to list
        bid_player_names_list.append(player_name)
        bid_player_teams_list.append(player_team)
        winning_offers_list.append(winning_offer)
        other_bids_list.append(other_bids)
    
    # Loop to retrieve team and date of winning bids
    winning_teams = []
    winning_dates = []
    elements = driver.find_elements_by_class_name('Grid-h-top')
    for element in elements:
        team = element.text.split('\n')[0]
        trans_date = element.text.split('\n')[1].split(',')[0] + ' 2020'
        winning_teams.append(team)
        winning_dates.append(trans_date)
    
#     # Loop to retrieve team and date of winning bids
#     winning_teams = []
#     winning_dates = []
#     elements = driver.find_elements_by_class_name('Grid-h-top')
#     for element in elements:
#         team = element.text.split('\n')[0]
#         trans_date = element.text.split('\n')[1].split(',')[0] + ' 2020'
#         winning_teams.append(team)
#         winning_dates.append(trans_date)
    
    faab_df = pd.DataFrame(
        columns=['Player Name', 'Player Team', 'Player Position', 'Bid Date', 'Winning Team', 'Winning Bid',
                 'Second Bid', 'Second Bid Team', 'Last Bid', 'Last Bid Team', 'Other Bids'])
    faab_df['Player Name'] = bid_player_names_list
    faab_df['Player Team'] = bid_player_teams_list
    faab_df['Player Position'] = bid_player_pos_list
    faab_df['Bid Date'] = winning_dates
    faab_df['Winning Team'] = winning_teams
    faab_df['Winning Bid'] = winning_offers_list
    faab_df['Second Bid'] = second_offers_list
    faab_df['Second Bid Team'] = second_team_list
    faab_df['Last Bid'] = last_offers_list
    faab_df['Last Bid Team'] = last_team_list
    faab_df['Other Bids'] = other_bids_list
    
    master_faab_df = pd.concat([master_faab_df, faab_df], axis=0)
    
    try:
        driver.find_element_by_partial_link_text('Next 25').click()
    
    except:
        break

# %%
# print(len(bid_player_names_list))
# print(len(bid_player_teams_list))
# print(len(bid_player_pos_list))
# print(len(winning_dates))
# print(len(winning_teams))
# print(len(winning_offers_list))
# print(len(second_offers_list))
# print(len(second_team_list))
# print(len(last_offers_list))
# print(len(last_team_list))
# print(len(other_bids_list))

# %%
# Write DataFrame to csv in project directory
dt_string = datetime.now().strftime('%Y%m%d_%H%M%S')
master_faab_df.to_csv(
    'C:\\Users\\David\\Desktop\\Fantasy Football\\Blastoff Boys Rosters\\FAAB\\blastoff_boys_faab_{}.csv'.format(dt_string))

# %%
master_faab_df
# Out:
#                  Player Name Player Team Player Position     Bid Date  \
# 0                 John Brown         Buf              WR  Dec 23 2020
# 1            Lynn Bowden Jr.         Mia           WR,RB  Dec 16 2020
# 2                 Ty Johnson         NYJ              RB  Dec 10 2020
# 3              Jakobi Meyers          NE              WR   Dec 6 2020
# 4                Los Angeles         LAR             DEF   Dec 6 2020
# 5                  Zach Ertz         Phi              TE   Dec 4 2020
# 6                Denzel Mims         NYJ              WR   Dec 4 2020
# 7                Keke Coutee         Hou              WR   Dec 4 2020
# 8                Kansas City          KC             DEF   Dec 4 2020
# 9               Tony Pollard         Dal              RB  Nov 25 2020
# 10                   Seattle         Sea             DEF  Nov 25 2020
# 11            Nelson Agholor          LV              WR  Nov 25 2020
# 12                   Buffalo         Buf             DEF  Nov 25 2020
# 13                Washington         Was             DEF  Nov 18 2020
# 14             Kalen Ballage         LAC              RB  Nov 18 2020
# 15               Los Angeles         LAC             DEF  Nov 18 2020
# 16            Jameis Winston          NO              QB  Nov 18 2020
# 17                 Minnesota         Min             DEF  Nov 11 2020
# 18             Jakobi Meyers          NE              WR  Nov 11 2020
# 19            Tua Tagovailoa         Mia              QB  Nov 11 2020
# 20                Brian Hill         Atl              RB   Nov 4 2020
# 21            Mark Ingram II         Bal              RB   Nov 4 2020
# 22               Tyler Ervin          GB              RB   Nov 4 2020
# 23            Jordan Wilkins         Ind              RB   Nov 4 2020
# 24               New England          NE             DEF  Oct 31 2020
# 0            Rashard Higgins         Cle              WR  Oct 28 2020
# 1           Sterling Shepard         NYG              WR  Oct 28 2020
# 2              Brandon Aiyuk          SF              WR  Oct 28 2020
# 3                Carlos Hyde         Sea              RB  Oct 28 2020
# 4             Nelson Agholor          LV              WR  Oct 28 2020
# ..                       ...         ...             ...          ...
# 21                 Tennessee         Ten             DEF  Oct 15 2020
# 22                Brian Hill         Atl              RB  Oct 10 2020
# 23             Robert Tonyan          GB              TE   Oct 7 2020
# 24      Laviska Shenault Jr.         Jax              WR   Oct 7 2020
# 0           D'Ernest Johnson         Cle              RB   Oct 7 2020
# 1             Justin Jackson         LAC              RB   Oct 7 2020
# 2               Damiere Byrd          NE              WR   Oct 7 2020
# 3               Logan Thomas         Was              TE   Oct 3 2020
# 4   Marquez Valdes-Scantling          GB              WR   Oct 3 2020
# 5                Tee Higgins         Cin              WR  Sep 30 2020
# 6             Chris Thompson         Jax              RB  Sep 30 2020
# 7                     Denver         Den             DEF  Sep 30 2020
# 8               Jimmy Graham         Chi              TE  Sep 30 2020
# 9                Sony Michel          NE              RB  Sep 30 2020
# 10                Eric Ebron         Pit              TE  Sep 30 2020
# 11           Phillip Lindsay         Den              RB  Sep 30 2020
# 12              Rex Burkhead          NE              RB  Sep 30 2020
# 13                Mike Davis         Car              RB  Sep 23 2020
# 14                Dion Lewis         NYG              RB  Sep 23 2020
# 15                 Tampa Bay          TB             DEF  Sep 23 2020
# 16            Dalton Schultz         Dal              TE  Sep 23 2020
# 17           Keelan Cole Sr.         Jax              WR  Sep 23 2020
# 18              Indianapolis         Ind             DEF  Sep 23 2020
# 19               Los Angeles         LAR             DEF  Sep 16 2020
# 20              Logan Thomas         Was              TE  Sep 16 2020
# 21              Russell Gage         Atl              WR  Sep 16 2020
# 22                   Arizona         Ari             DEF  Sep 16 2020
# 23             Peyton Barber         Was              RB  Sep 16 2020
# 24             Scotty Miller          TB              WR  Sep 16 2020
# 0               Jalen Reagor         Phi              WR  Sep 11 2020
#
#             Winning Team Winning Bid Second Bid       Second Bid Team  \
# 0   Doctor Steal Yo Girl           1          0      First Round Exit
# 1    CeeDeeZ Rugged Nuts          12          6  Doctor Steal Yo Girl
# 2     CreamTeam Curdlers          15          5      Bidet to You Sir
# 3      Child Butt Doctor           0          0      First Round Exit
# 4       First Round Exit           0          0      First Round Exit
# 5            Florida Man          12          0   CeeDeeZ Rugged Nuts
# 6   JohnDavidBootyShorts           0          0      First Round Exit
# 7   Doctor Steal Yo Girl          15          8      Bidet to You Sir
# 8   JohnDavidBootyShorts          58         10           Florida Man
# 9       Bidet to You Sir           3          0      First Round Exit
# 10  Doctor Steal Yo Girl           5          3           Florida Man
# 11  JohnDavidBootyShorts           5          1   CeeDeeZ Rugged Nuts
# 12      Bidet to You Sir           4          2  Doctor Steal Yo Girl
# 13      First Round Exit           1          0  Doctor Steal Yo Girl
# 14  JohnDavidBootyShorts          25          3      First Round Exit
# 15         My Dick Sucks          10          1  JohnDavidBootyShorts
# 16  Doctor Steal Yo Girl           5          0     North Source Boys
# 17     Child Butt Doctor           4          1           Florida Man
# 18    CreamTeam Curdlers          13          8  Doctor Steal Yo Girl
# 19      Betty Boop Would          13          3   CeeDeeZ Rugged Nuts
# 20  Doctor Steal Yo Girl          12          0      First Round Exit
# 21      Bidet to You Sir           4          0      First Round Exit
# 22  Doctor Steal Yo Girl           9          6           Florida Man
# 23      Betty Boop Would          13          9  Doctor Steal Yo Girl
# 24     Child Butt Doctor           3          0      Bidet to You Sir
# 0       Betty Boop Would          10          3    CreamTeam Curdlers
# 1     CreamTeam Curdlers          16         12  JohnDavidBootyShorts
# 2       First Round Exit          24         22     OnlyFans Cam Girl
# 3      OnlyFans Cam Girl          18          8      Betty Boop Would
# 4       Bidet to You Sir           5          5      Bidet to You Sir
# ..                   ...         ...        ...                   ...
# 21     OnlyFans Cam Girl           8          0  JohnDavidBootyShorts
# 22      Bidet to You Sir           1          1  Doctor Steal Yo Girl
# 23     North Source Boys          40         28  Doctor Steal Yo Girl
# 24    CreamTeam Curdlers          16          8     OnlyFans Cam Girl
# 0      North Source Boys          25         15     OnlyFans Cam Girl
# 1      Child Butt Doctor          25         16    CreamTeam Curdlers
# 2      OnlyFans Cam Girl           3          0  JohnDavidBootyShorts
# 3       Bidet to You Sir           5          0     Child Butt Doctor
# 4       First Round Exit          14         11    CreamTeam Curdlers
# 5      Child Butt Doctor          11          6    CreamTeam Curdlers
# 6      North Source Boys           0          0   CeeDeeZ Rugged Nuts
# 7      OnlyFans Cam Girl           8          2  Doctor Steal Yo Girl
# 8            Florida Man          12          6      Bidet to You Sir
# 9            Florida Man           6          5    CreamTeam Curdlers
# 10      First Round Exit           5          2      Bidet to You Sir
# 11    CreamTeam Curdlers           6          3      Bidet to You Sir
# 12      Betty Boop Would          11         10      Bidet to You Sir
# 13      First Round Exit          42         36      Bidet to You Sir
# 14      Betty Boop Would          20         14      Bidet to You Sir
# 15      Bidet to You Sir           0          0    CreamTeam Curdlers
# 16     OnlyFans Cam Girl          25         11           Florida Man
# 17      Bidet to You Sir           8          5     Child Butt Doctor
# 18      First Round Exit           4          0    CreamTeam Curdlers
# 19     Child Butt Doctor           5          0  JohnDavidBootyShorts
# 20   CeeDeeZ Rugged Nuts          10          5      Bidet to You Sir
# 21           Florida Man          31          4     Child Butt Doctor
# 22      First Round Exit           2          1      Betty Boop Would
# 23   CeeDeeZ Rugged Nuts          16          0      Betty Boop Would
# 24     North Source Boys           5          4     Child Butt Doctor
# 0   Doctor Steal Yo Girl           2          1      Bidet to You Sir
#
#    Last Bid         Last Bid Team  \
# 0         0      First Round Exit
# 1         6  Doctor Steal Yo Girl
# 2         0  Doctor Steal Yo Girl
# 3         0      First Round Exit
# 4         0      First Round Exit
# 5         0   CeeDeeZ Rugged Nuts
# 6         0      First Round Exit
# 7         0   CeeDeeZ Rugged Nuts
# 8         0      First Round Exit
# 9         0      First Round Exit
# 10        3           Florida Man
# 11        0     North Source Boys
# 12        2  Doctor Steal Yo Girl
# 13        0  Doctor Steal Yo Girl
# 14        0     OnlyFans Cam Girl
# 15        1  JohnDavidBootyShorts
# 16        0     North Source Boys
# 17        1           Florida Man
# 18        0     OnlyFans Cam Girl
# 19        3   CeeDeeZ Rugged Nuts
# 20        0      First Round Exit
# 21        0      First Round Exit
# 22        6           Florida Man
# 23        9  Doctor Steal Yo Girl
# 24        0      Bidet to You Sir
# 0         0      First Round Exit
# 1         4      Bidet to You Sir
# 2         3   CeeDeeZ Rugged Nuts
# 3         3  JohnDavidBootyShorts
# 4         2   CeeDeeZ Rugged Nuts
# ..      ...                   ...
# 21        0  JohnDavidBootyShorts
# 22        1  Doctor Steal Yo Girl
# 23        5    CreamTeam Curdlers
# 24        0      First Round Exit
# 0         0  JohnDavidBootyShorts
# 1         6     OnlyFans Cam Girl
# 2         0  JohnDavidBootyShorts
# 3         0     Child Butt Doctor
# 4         0      Betty Boop Would
# 5         3      Bidet to You Sir
# 6         0   CeeDeeZ Rugged Nuts
# 7         2  Doctor Steal Yo Girl
# 8         3      First Round Exit
# 9         4      Bidet to You Sir
# 10        2      Bidet to You Sir
# 11        0  Doctor Steal Yo Girl
# 12       10      Bidet to You Sir
# 13       22     Child Butt Doctor
# 14        7   CeeDeeZ Rugged Nuts
# 15        0    CreamTeam Curdlers
# 16        6      Bidet to You Sir
# 17        0      Betty Boop Would
# 18        0    CreamTeam Curdlers
# 19        0  JohnDavidBootyShorts
# 20        0      First Round Exit
# 21        4     Child Butt Doctor
# 22        1      Betty Boop Would
# 23        0      Betty Boop Would
# 24        0      Betty Boop Would
# 0         1      Bidet to You Sir
#
#                                            Other Bids
# 0                                 First Round Exit $0
# 1                             Doctor Steal Yo Girl $6
# 2   Bidet to You Sir $5, CeeDeeZ Rugged Nuts $3, D...
# 3                                 First Round Exit $0
# 4                                 First Round Exit $0
# 5                              CeeDeeZ Rugged Nuts $0
# 6                                 First Round Exit $0
# 7   Bidet to You Sir $8, CeeDeeZ Rugged Nuts $0, F...
# 8                Florida Man $10, First Round Exit $0
# 9                                 First Round Exit $0
# 10                                     Florida Man $3
# 11       CeeDeeZ Rugged Nuts $1, North Source Boys $0
# 12                            Doctor Steal Yo Girl $2
# 13                            Doctor Steal Yo Girl $0
# 14  First Round Exit $3, CeeDeeZ Rugged Nuts $1, O...
# 15                            JohnDavidBootyShorts $1
# 16                               North Source Boys $0
# 17            Florida Man $1, Doctor Steal Yo Girl $1
# 18  Doctor Steal Yo Girl $8, CeeDeeZ Rugged Nuts $...
# 19                             CeeDeeZ Rugged Nuts $3
# 20                                First Round Exit $0
# 21                                First Round Exit $0
# 22                                     Florida Man $6
# 23                            Doctor Steal Yo Girl $9
# 24                                Bidet to You Sir $0
# 0          CreamTeam Curdlers $3, First Round Exit $0
# 1   JohnDavidBootyShorts $12, CreamTeam Curdlers $...
# 2   OnlyFans Cam Girl $22, JohnDavidBootyShorts $1...
# 3        Betty Boop Would $8, JohnDavidBootyShorts $3
# 4         Bidet to You Sir $5, CeeDeeZ Rugged Nuts $2
# ..                                                ...
# 21                            JohnDavidBootyShorts $0
# 22                            Doctor Steal Yo Girl $1
# 23    Doctor Steal Yo Girl $28, CreamTeam Curdlers $5
# 24  OnlyFans Cam Girl $8, Bidet to You Sir $7, Doc...
# 0   OnlyFans Cam Girl $15, Doctor Steal Yo Girl $8...
# 1        CreamTeam Curdlers $16, OnlyFans Cam Girl $6
# 2                             JohnDavidBootyShorts $0
# 3                                Child Butt Doctor $0
# 4   CreamTeam Curdlers $11, Bidet to You Sir $7, B...
# 5   CreamTeam Curdlers $6, Bidet to You Sir $3, Do...
# 6                              CeeDeeZ Rugged Nuts $0
# 7                             Doctor Steal Yo Girl $2
# 8            Bidet to You Sir $6, First Round Exit $3
# 9          CreamTeam Curdlers $5, Bidet to You Sir $4
# 10                                Bidet to You Sir $2
# 11       Bidet to You Sir $3, Doctor Steal Yo Girl $0
# 12       Bidet to You Sir $10, CreamTeam Curdlers $10
# 13        Bidet to You Sir $36, Child Butt Doctor $22
# 14       Bidet to You Sir $14, CeeDeeZ Rugged Nuts $7
# 15                              CreamTeam Curdlers $0
# 16  Florida Man $11, Child Butt Doctor $7, Bidet t...
# 17  Child Butt Doctor $5, First Round Exit $1, Bet...
# 18                              CreamTeam Curdlers $0
# 19                            JohnDavidBootyShorts $0
# 20  Bidet to You Sir $5, CeeDeeZ Rugged Nuts $2, F...
# 21                               Child Butt Doctor $4
# 22                                Betty Boop Would $1
# 23                                Betty Boop Would $0
# 24          Child Butt Doctor $4, Betty Boop Would $0
# 0                                 Bidet to You Sir $1
#
# [76 rows x 11 columns]

# %%
# ### TEST DELETE

# # Loop to retrieve transactions
# test_bid_player_names_list = []
# test_bid_player_teams_list = []
# test_bid_player_pos_list = []
# test_winning_offers_list = []
# test_second_offers_list = []
# test_second_team_list = []
# test_last_offers_list = []
# test_last_team_list = []
# test_other_bids_list = []
# elements = driver.find_elements_by_class_name('No-pstart')
# for element in elements:
#     player_name_team = element.text.split('\n')[0].split(' - ')[0]
#     last_space_in_player_name = max(
#         list([pos for pos, char in enumerate(player_name_team) if char == ' ']))
#     player_name = player_name_team[0:last_space_in_player_name]
#     player_team = player_name_team[last_space_in_player_name + 1:]
#     player_pos = element.text.split('\n')[0].split(' - ')[1].split(' ')[0]
#     test_bid_player_pos_list.append(player_pos)
# #     print(player_pos)
# #     for pos in position_abbrevs_list:
# #         if pos in player_pos:
# #             test_bid_player_pos_list.append(player_pos)
#     winning_offer = int(element.text.split('\n')[1].replace(' Winning Offer', '').replace('$',''))

#     # Retrieve info about other bids for this player
#     other_bids = str(element.text.split('\n')[2:]).replace(' (Lower Offer)', '').replace(
#         ' (Lower waiver priority)', '').replace(' (Invalid claim due to previous transaction)', '').replace(
#         '[', '').replace(']', '').replace("'", "").replace('"', '')
#     bids_split = other_bids.split(',')
#     bids_split_cleaned = []
#     teams_making_bids = []
#     for bid in bids_split:
#         bid = bid.replace('$', '')
#         for team in non_apostraphe_team_names:
#             if team in bid:
#                 teams_making_bids.append(apostraphe_lookup_dict[team])
#                 bid = bid.replace(team, '')
#         bid = bid.replace(' ', '')
#         bids_split_cleaned.append(int(bid))
#     max_bid = max(bids_split_cleaned) # Find max bid and associated team
#     index_max_bid = bids_split_cleaned.index(max_bid)
#     team_max_bid = teams_making_bids[index_max_bid]
#     second_offers_list.append(max_bid)
#     second_team_list.append(team_max_bid)
#     min_bid = min(bids_split_cleaned) # Find min bid and associated team
#     index_min_bid = bids_split_cleaned.index(min_bid)
#     team_min_bid = teams_making_bids[index_min_bid]
#     last_offers_list.append(min_bid)
#     last_team_list.append(team_min_bid)

#     # Append other elements to list
#     test_bid_player_names_list.append(player_name)
#     test_bid_player_teams_list.append(player_team)
#     test_winning_offers_list.append(winning_offer)
#     test_other_bids_list.append(other_bids)

# # Loop to retrieve team and date of winning bids
# test_winning_teams = []
# test_winning_dates = []
# elements = driver.find_elements_by_class_name('Grid-h-top')
# for element in elements:
#     team = element.text.split('\n')[0]
#     trans_date = element.text.split('\n')[1].split(',')[0] + ' 2020'
#     test_winning_teams.append(team)
#     test_winning_dates.append(trans_date)

# # # Loop to retrieve team and date of winning bids
# # winning_teams = []
# # winning_dates = []
# # elements = driver.find_elements_by_class_name('Grid-h-top')
# # for element in elements:
# #     team = element.text.split('\n')[0]
# #     trans_date = element.text.split('\n')[1].split(',')[0] + ' 2020'
# #     winning_teams.append(team)
# #     winning_dates.append(trans_date)

# print(len(test_bid_player_names_list))
# print(len(test_bid_player_teams_list))
# print(len(test_bid_player_pos_list))
# print(len(test_winning_dates))
# print(len(test_winning_teams))
# print(len(test_winning_offers_list))
# print(len(test_second_offers_list))
# print(len(test_second_team_list))
# print(len(test_last_offers_list))
# print(len(test_last_team_list))
# print(len(test_other_bids_list))

# %%
# Navigate to transactions page
transactions_url = league_url + 'transactions'
driver.get(transactions_url) # navigate to each team's roster per week

# Navigate to faab bids history
driver.find_element_by_partial_link_text('FAB Offers').click()
time.sleep(1) # force wait for loading

# %%
# Loop to retrieve transactions
bid_player_names_list = []
bid_player_teams_list = []
bid_player_pos_list = []
winning_offers_list = []
other_bids_list = []
elements = driver.find_elements_by_class_name('No-pstart')
for element in elements:
    player_name_team = element.text.split('\n')[0].split(' - ')[0]
    last_space_in_player_name = max(
        [pos for pos, char in enumerate(player_name_team) if char == ' '])
    player_name = player_name_team[0:last_space_in_player_name]
    player_team = player_name_team[last_space_in_player_name + 1:]
    player_pos = element.text.split('\n')[0].split(' - ')[1].split(' ')[0]
    for pos in position_abbrevs_list:
        if pos in player_pos:
            bid_player_pos_list.append(pos)
    winning_offer = int(element.text.split('\n')[1].replace(' Winning Offer', '').replace('$',''))
    other_bids = str(element.text.split('\n')[2:]).replace(' (Lower Offer)','').replace(
        ' (Lower waiver priority)','').replace(' (Invalid claim due to previous transaction)','').replace(
        '[','').replace(']','').replace("'","").replace('"','')
    bid_player_names_list.append(player_name)
    bid_player_teams_list.append(player_team)
    winning_offers_list.append(winning_offer)
    other_bids_list.append(other_bids)

# %%
print(bid_player_names_list[2])
print(bid_player_teams_list[2])
print(bid_player_pos_list[2])
print(winning_offers_list[2])
print(other_bids_list[2])
# Out:
# Ty Johnson
# NYJ
# WR
# 15
# Bidet to You Sir $5, CeeDeeZ Rugged Nuts $3, Doctor Steal Yo Girl $0

# %%
team_ints_to_names.values()
# Out:
# dict_values(['Child Butt Doctor', 'CreamTeam Curdlers', 'First Round Exit', 'OOO Till Playoffs', 'JohnDavidBootyShorts', 'Bidet to You Sir', 'Doctor Steal Yo Girl', 'Betty Boop Would', 'OnlyFans Cam Girl', 'My Dick Sucks', 'Florida Man', 'North Source Boys'])

# %%
bids_split = other_bids_list[2].split(',')
bids_split

bids_split_cleaned = []
teams_making_bids = []
for bid in bids_split:
    bid = bid.replace('$','')
    for team in list(team_ints_to_names.values()):
        if team in bid:
            teams_making_bids.append(team)
            bid = bid.replace(team, '')
    bid = bid.replace(' ', '')
    bids_split_cleaned.append(int(bid))

# Find max bid and associated team
max_bid = max(bids_split_cleaned)
index_max_bid = bids_split_cleaned.index(max_bid)
team_max_bid = teams_making_bids[index_max_bid]

# Find min bid and associated team
min_bid = min(bids_split_cleaned)
index_min_bid = bids_split_cleaned.index(min_bid)
team_min_bid = teams_making_bids[index_min_bid]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-52f201c41760> in <module>
#      11             bid = bid.replace(team, '')
#      12     bid = bid.replace(' ', '')
# ---> 13     bids_split_cleaned.append(int(bid))
#      14
#      15 # Find max bid and associated team
#
# ValueError: invalid literal for int() with base 10: 'CeeDeeZRuggedNuts3'

# %%
bid
# Out:
# 'CeeDeeZRuggedNuts3'

# %%
print(max_bid)
print(team_max_bid)
print(min_bid)
print(team_min_bid)
# Out:
# 0
# First Round Exit
# 0
# First Round Exit

# %%
bids_split_cleaned = []
teams_making_bids = []
for bid in bids_split:
    bid = bid.replace('$','')
    for team in list(team_ints_to_names.values()):
        if team in bid:
            teams_making_bids.append(team)
            bid = bid.replace(team, '')
    bid = bid.replace(' ', '')
    bids_split_cleaned.append(int(bid))

# Find max bid and associated team
max_bid = max(bids_split_cleaned)
index_max_bid = bids_split_cleaned.index(max_bid)
team_max_bid = teams_making_bids[index_max_bid]

# Find min bid and associated team
min_bid = min(bids_split_cleaned)
index_min_bid = bids_split_cleaned.index(min_bid)
team_min_bid = teams_making_bids[index_min_bid]

# %%
print(max_bid)
print(index_max_bid)
print(team_max_bid)
print(min_bid)
print(index_min_bid)
print(team_min_bid)
# Out:
# 0
# 0
# First Round Exit
# 0
# 0
# First Round Exit

# %%
# Loop to retrieve team and date of winning bids
winning_teams = []
winning_dates = []
elements = driver.find_elements_by_class_name('Grid-h-top')
for element in elements:
    team = element.text.split('\n')[0]
    trans_date = element.text.split('\n')[1].split(',')[0] + ' 2020'
    winning_teams.append(team)
    winning_dates.append(trans_date)

# %%
bids_split_cleaned
# Out:
# [0]

# %%
# print(winning_teams[0:5])
# print(winning_dates[0:5])

# %%
faab_df = pd.DataFrame(columns=['Player Name', 'Player Team', 'Player Position',
                                'Winning Team', 'Winning Bid', 'Bid Date', 'Other Bids'])
faab_df['Player Name'] = bid_player_names_list
faab_df['Player Team'] = bid_player_teams_list
faab_df['Player Position'] = bid_player_pos_list
faab_df['Winning Team'] = winning_teams
faab_df['Winning Bid'] = winning_offers_list
faab_df['Bid Date'] = winning_dates
faab_df['Other Bids'] = other_bids_list
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8afa21836510> in <module>
#       3 faab_df['Player Name'] = bid_player_names_list
#       4 faab_df['Player Team'] = bid_player_teams_list
# ----> 5 faab_df['Player Position'] = bid_player_pos_list
#       6 faab_df['Winning Team'] = winning_teams
#       7 faab_df['Winning Bid'] = winning_offers_list
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
faab_df.head()
# Out:
#        Player Name Player Team Player Position Winning Team Winning Bid  \
# 0       John Brown         Buf             NaN          NaN         NaN
# 1  Lynn Bowden Jr.         Mia             NaN          NaN         NaN
# 2       Ty Johnson         NYJ             NaN          NaN         NaN
# 3    Jakobi Meyers          NE             NaN          NaN         NaN
# 4      Los Angeles         LAR             NaN          NaN         NaN
#
#   Bid Date Other Bids
# 0      NaN        NaN
# 1      NaN        NaN
# 2      NaN        NaN
# 3      NaN        NaN
# 4      NaN        NaN

# %% [markdown]
# ## <font color='teal'>Test Individual Team/Week</font>

# %%
# test_df = rosterExtract(urls_list[38], team_ints_to_names)

# %%
# test_df

# %%
# control = 0
# print(len(test_df[control]))
# test_df[control]

# %% [markdown]
# ## <font color='teal'>Original Component Code</font>

# %%
# # Navigate to first team's webpage
# driver.get(team_urls_dict['Team1'])

# %%
# # navigate to week 1 for this team
# driver.get(team_urls_dict['Team1']+'/team?&week=1')

# %%
# # roster table
# roster_xpath = '//*[@id="statTable0"]'
# driver.find_element_by_xpath(roster_xpath).click()

# %%
# # find by partial href url tutorial
# elements = driver.find_elements_by_xpath("//a[contains(@href, '/mathscinet/search/mscdoc.html')]")
# for element in elements:
#     print(element.text)

# %%
# # Loop through and retrieve players by href
# players_list = []
# elements = driver.find_elements_by_xpath('//a[contains(@href, "https://sports.yahoo.com/nfl/")]')
# # elements = driver.find_elements_by_xpath('//a[contains(@href, "https://sports.yahoo.com/nfl/players/")]')
# for element in elements:
#     if element.text != '' and\
#     '@' not in element.text and\
#     'StatTracker' not in element.text and\
#     'vs' not in element.text:
#         players_list.append(element.text)

# %%
# players_list

# %%
# find_elements_by_tag_name
# find_elements_by_class_name

# %%
# # Loop through and retrieve game statuses by class
# game_status_list = []
# win_loss_list = []
# elements = driver.find_elements_by_class_name('ysf-game-status')
# for element in elements:
#     if 'Bye' in element.text:
#         game_status_list.append('Bye')
#     elif 'vs' in element.text:
#         game_status_list.append('Home')
#     elif '@' in element.text:
#         game_status_list.append('Away')
#     else:
#         game_status_list.append('N/A')
# for element in elements:
#     if 'Bye' in element.text:
#         win_loss_list.append('Bye')
#     elif 'Final W' in element.text:
#         win_loss_list.append('W')
#     elif 'Final L' in element.text:
#         win_loss_list.append('L')
#     elif 'Final T' in element.text:
#         win_loss_list.append('T')
#     else:
#         win_loss_list.append('N/A')

# %%
# game_status_list
# win_loss_list

# %%
# # Loop through and retrieve empty roster spots (e.g., played only 1RB, left 2RB empty) by class
# empty_spot_list = []
# elements = driver.find_elements_by_class_name('Nowrap emptyplayer')
# for element in elements:
#     empty_spot_list.append(element.text)

# %%
# empty_spot_list

# %%
# # Insert "Empty" tag to player roster where Bye week is Null
# empty_spot_indexes = []
# counter = 0
# for status in game_status_list:
#     counter += 1
#     if status == 'N/A':
#         empty_spot_indexes.append(counter-1)
# for i in empty_spot_indexes:
#     players_list.insert(i, 'Empty')

# %%
# empty_spot_indexes

# %%
# # Loop through and retrieve positions by class
# positions_list = []
# elements = driver.find_elements_by_class_name('pos-label')
# for element in elements:
# #     if element.text != '':
#     positions_list.append(element.text)

# %%
# positions_list

# %%
# # Loop through and retrieve player teams and positions by class
# player_team_list = []
# player_pos_list = []
# elements = driver.find_elements_by_class_name('Fz-xxs')
# for element in elements:
#     if ' - ' in element.text:
#         element_tuple = element.text.split(' - ', 1)
#         team = element_tuple[0]
#         pos = element_tuple[1]
#         if pos in ['QB', 'RB', 'WR', 'TE', 'DEF', 'K',
#                    'WR,RB', 'RB,WR', 'QB,WR', 'QB,RB',
#                    'QB,TE', 'WR,TE', 'TE,WR', 'TE,RB']:
#             player_team_list.append(team)
#             player_pos_list.append(pos)

# %%
# player_team_list
# player_pos_list

# %%
# # Loop through and retrieve positions by class
# actual_points = []
# elements = driver.find_elements_by_class_name('pps Fw-b has-stat-note ')
# for element in elements:
# #     if element.text != '':
#     actual_points.append(element.text)

# %%
# actual_points

# %%
# # Loop through and retrieve actual points by href
# points_as_strings = []
# # counter = 0
# elements = driver.find_elements_by_xpath('//a[contains(@href, "#pps-")]')
# for element in elements:
# #     counter += 1
# #     if game_status_list[counter-1] == 'Bye':
# #         points_as_strings.append('0')
#     if element.text != '':
#         points_as_strings.append(element.text)

# # Convert strings to floats
# points_as_floats = [float(pt) for pt in points_as_strings]

# # Insert zero floats where player on bye
# game_status_indexes = []
# counter = 0
# for status in game_status_list:
#     counter += 1
#     if status == 'Bye':
#         game_status_indexes.append(counter-1)
# for i in game_status_indexes:
#     points_as_floats.insert(i, 0.00)

# %%
# points_as_floats

# %%
# # Build table from lists, write to DataFrame
# roster_df = pd.DataFrame(columns=['Player', 'Status', 'Player Team', 'Position', 'Points'])
# roster_df['Player'] = players_list
# roster_df['Status'] = positions_list
# roster_df['Player Team'] = player_team_list
# roster_df['Position'] = player_pos_list
# roster_df['Points'] = points_as_floats

# %%
# roster_df

# %%
# print(len(players_list))
# print(len(positions_list))
# print(len(player_team_list))
# print(len(player_pos_list))
# print(len(points_as_floats))
